# %%
from selenium import webdriver

# %%
#!pip install selenium
# Out:
# Collecting selenium
#   Using cached https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl
# Requirement already satisfied: urllib3 in c:\users\lgpc\anaconda3\lib\site-packages (from selenium) (1.24.2)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0

# %%
url = 'http://www.itworld.co.kr/search/?q=AI'  #.format(page)

# %%
#from selenium.webdriver.common.keys import Keys
import time

driver =  webdriver.Chrome()
driver.get(url)

driver.implicitly_wait(5)

div = driver.find_elements_by_css_selector('.gsc-wrapper')[0]
btn = div.find_elements_by_css_selector('.gsc-cursor-page')[2]

btn.click()

#driver.find_element_by_xpath("""//*[@id="___gcse_0"]/div/div/div/div[5]/div[2]/div[1]/div/div[2]/div/div[5]""").click()

# %%
#여러데이터 모으기
articles = driver.find_elements_by_css_selector("#___gcse_0 > div > div > div > div.gsc-wrapper > div.gsc-resultsbox-visible > div.gsc-resultsRoot.gsc-tabData.gsc-tabdActive > div > div.gsc-expansionArea > div > div.gs-webResult.gs-result")
                                                

len(articles)
# Out:
# 10

# %%
#제목 뽑기  > 

import pandas as pd

title_list = []
for article in articles:
    title = article.find_element_by_css_selector("div.gsc-thumbnail-inside > div > a").text 
    title_list.append(title)
title =pd.DataFrame(title_list, columns=['title'])
title.head()
# Out:
#                                                title
# 0     CJ올리브네트웍스, 전 직원에 AI 아카데미 교육 실시 - ITWorld Korea
# 1  성공적인 AI 도입을 위한 실전 가이드 - IDG Tech Dossier - ITW...
# 2  RPA, AI, 데이터옵스 등 2020년 주시해야 할 기술 8가지 - ITWorld...
# 3        AI의 진화는 어디까지...장편 영화 대본도 썼다 - ITWorld Korea
# 4        화웨이, 신형 AI 칩으로 엔비디아와 인텔 노린다 - ITWorld Korea

# %%
# 링크 뽑기
#___gcse_1 > div > div > div > div.gsc-wrapper > div.gsc-resultsbox-visible > div.gsc-resultsRoot.gsc-tabData.gsc-tabdActive > div > div.gsc-expansionArea > div:nth-child(1) > div.gs-webResult.gs-result > div.gsc-url-top > div.gs-bidi-start-align.gs-visibleUrl.gs-visibleUrl-long

link_list = []
for article in articles:
    link = article.find_element_by_css_selector("div.gsc-url-top > div.gs-bidi-start-align.gs-visibleUrl.gs-visibleUrl-long").text #get_attribute("href")
    link_list.append(link)
link= pd.DataFrame(link_list, columns=['link'])
link.head() #상위 5개 보여줌
# Out:
#                                    link
# 0         www.itworld.co.kr/news/123027
# 1  www.itworld.co.kr/techlibrary/108332
# 2         www.itworld.co.kr/news/129735
# 3         www.itworld.co.kr/news/100527
# 4     www.itworld.co.kr/news/111099화웨이의

# %%
# articles[0].text
#div.gsc-table-result > div.gsc-table-cell-thumbnail.gsc-thumbnail > div > a > img

img_list = []
for article in articles:
    img = article.find_element_by_css_selector("div.gsc-table-result > div.gsc-table-cell-thumbnail.gsc-thumbnail > div > a > img").get_attribute("src") 
    img_list.append(img)
img=pd.DataFrame(img_list,columns=['img'])
img.head()
# Out:
#                                                  img
# 0  https://encrypted-tbn2.gstatic.com/images?q=tb...
# 1  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 2  https://encrypted-tbn1.gstatic.com/images?q=tb...
# 3  https://encrypted-tbn3.gstatic.com/images?q=tb...
# 4  https://encrypted-tbn1.gstatic.com/images?q=tb...

# %%
result=pd.concat([img, title, link], axis=1)
result.tail() #하위5개 보여줌
# Out:
#                                                  img  \
# 5  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 6  https://encrypted-tbn2.gstatic.com/images?q=tb...
# 7  https://encrypted-tbn2.gstatic.com/images?q=tb...
# 8  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 9  https://encrypted-tbn2.gstatic.com/images?q=tb...
#
#                                                title  \
# 5        AMD, 머신러닝용 라데온 인스팅트 GPU 발표…AI 시장 추격 나선다 ...
# 6  “2022년까지 AI 프로젝트 85%가 잘못된 결과 도출"…가트너 - ITWorld...
# 7         향후 10년 AI 투명성의 위험을 완화하는 방법 - ITWorld Korea
# 8  IDG 블로그 | SaaS 기반 AI 학습 서비스의 엄청난 가능성 - ITWorld...
# 9     마그넷 포렌식, AI 기능 더한 디지털 포렌식 솔루션 '마그넷 엑시엄 1.1 ...
#
#                             link
# 5  www.itworld.co.kr/news/102559
# 6  www.itworld.co.kr/news/108256
# 7  www.itworld.co.kr/news/140656
# 8  www.itworld.co.kr/news/137410
# 9  www.itworld.co.kr/news/105638

# %%
# 함수로 만들기
def get_articles(page):
    from selenium import webdriver
    import time
    import pandas as pd
    
    driver =  webdriver.Chrome()
    url = 'http://www.itworld.co.kr/search/?q=AI'#.format(page)
    driver.get(url)
       
    div = driver.find_elements_by_css_selector('.gsc-wrapper')[0]
    btn = div.find_elements_by_css_selector('.gsc-cursor-page')[3]

    btn.click()    
    time.sleep(1)
    #driver.find_element_by_xpath("""//*[@id="___gcse_0"]/div/div/div/div[5]/div[2]/div[1]/div/div[2]/div/div[%s]""" %page).click()
    
    #여러데이터 모으기
    articles = driver.find_elements_by_css_selector("#___gcse_0 > div > div > div > div.gsc-wrapper > div.gsc-resultsbox-visible > div.gsc-resultsRoot.gsc-tabData.gsc-tabdActive > div > div.gsc-expansionArea > div > div.gs-webResult.gs-result")
    
    
    #제목
    title_list = []
    for article in articles:
        title = article.find_element_by_css_selector("div.gsc-thumbnail-inside > div > a").text 
        title_list.append(title)
    title =pd.DataFrame(title_list, columns=['title'])
    
   
    #링크만 뽑아내기
    link_list = []
    for article in articles:
        link = article.find_element_by_css_selector("div.gsc-url-top > div.gs-bidi-start-align.gs-visibleUrl.gs-visibleUrl-long").text
        link_list.append(link)
    link= pd.DataFrame(link_list, columns=['link'])
    
    #이미지만 뽑아내기
    img_list = []
    for article in articles:
        img = article.find_element_by_css_selector("div.gsc-table-cell-thumbnail.gsc-thumbnail > div > a > img").get_attribute("src") 
        
        
        img_list.append(img)
    img=pd.DataFrame(img_list,columns=['img'])
    
    result=pd.concat([img, title, link], axis=1) #axis=1 은 열 !!! 
   
    driver.quit()
    return result

# %%
get_articles(5)
# Out:
#                                                  img  \
# 0  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 1  https://encrypted-tbn3.gstatic.com/images?q=tb...
# 2  https://encrypted-tbn2.gstatic.com/images?q=tb...
# 3  https://encrypted-tbn3.gstatic.com/images?q=tb...
# 4  https://encrypted-tbn3.gstatic.com/images?q=tb...
# 5  https://encrypted-tbn2.gstatic.com/images?q=tb...
# 6  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 7  https://encrypted-tbn3.gstatic.com/images?q=tb...
# 8  https://encrypted-tbn1.gstatic.com/images?q=tb...
# 9  https://encrypted-tbn3.gstatic.com/images?q=tb...
#
#                                                title  \
# 0         “데이터와 AI를 이용한 궁극의 개인화” 고객 생애 가치 향상을 위한 ...
# 1   자율 주행에서 머신 비전까지··· 'HPC+AI' HPE 글로벌 사례 집중 분석 ...
# 2  미스트 시스템즈, 'AI 기반 셀프 드라이빙 네트워크' 발표 - ITWorld Korea
# 3   글로벌 칼럼 | AI의 밝은 면에 기업이 집중해야 할 이유 - ITWorld Korea
# 4     성공을 위한 AI 모멘텀, 성숙도, 그리고 모델 : 글로벌 경영진 설문 조사 ...
# 5      IBM, AI 혁신 기능 추가 '왓슨 애니웨어' 공개 - ITWorld Korea
# 6            운영도구의 미래도 AI에 클라우드를 더한 '클라우드옵스'가 해답 ...
# 7  “차세대 IT 인프라 운영 관리는 AI가 맡는다” HPE InfoSight가 제시하...
# 8      부산은행 '리디자인 뱅킹' 사례로 본 혁신을 위한 AI와 데이터 활용 전략 ...
# 9   글로벌 칼럼 | 보안 업체들이 말하는 AI가 정말 AI인가 - ITWorld Korea
#
#                                    link
# 0  www.itworld.co.kr/techlibrary/125010
# 1  www.itworld.co.kr/techlibrary/122105
# 2         www.itworld.co.kr/news/136382
# 3         www.itworld.co.kr/news/140144
# 4  www.itworld.co.kr/techlibrary/113328
# 5         www.itworld.co.kr/news/134755
# 6         www.itworld.co.kr/news/119435
# 7  www.itworld.co.kr/techlibrary/122990
# 8  www.itworld.co.kr/techlibrary/136998
# 9         www.itworld.co.kr/news/108702

# %%
# 자동으로 일정 페이지 크롤링해줘서 데이터프레임 만들어주기
def Tech_crunch(startpage, endpage):
    import pandas as pd
    df=pd.DataFrame([])
    for i in range(startpage, endpage+1):
        temp=get_articles(i)
        df= pd.concat([df,temp],axis=0)
    #index 번호 다시 매기기
    df.reset_index(drop=True, inplace=True)
    return df

# %%
final_df= Tech_crunch(1,10)

# %%
final_df.tail(3)
#final_df
# Out:
#                                                   img  \
# 0   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 1   https://encrypted-tbn3.gstatic.com/images?q=tb...
# 2   https://encrypted-tbn2.gstatic.com/images?q=tb...
# 3   https://encrypted-tbn3.gstatic.com/images?q=tb...
# 4   https://encrypted-tbn3.gstatic.com/images?q=tb...
# 5   https://encrypted-tbn2.gstatic.com/images?q=tb...
# 6   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 7   https://encrypted-tbn3.gstatic.com/images?q=tb...
# 8   https://encrypted-tbn1.gstatic.com/images?q=tb...
# 9   https://encrypted-tbn3.gstatic.com/images?q=tb...
# 10  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 11  https://encrypted-tbn3.gstatic.com/images?q=tb...
# 12  https://encrypted-tbn2.gstatic.com/images?q=tb...
# 13  https://encrypted-tbn3.gstatic.com/images?q=tb...
# 14  https://encrypted-tbn3.gstatic.com/images?q=tb...
# 15  https://encrypted-tbn2.gstatic.com/images?q=tb...
# 16  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 17  https://encrypted-tbn3.gstatic.com/images?q=tb...
# 18  https://encrypted-tbn1.gstatic.com/images?q=tb...
# 19  https://encrypted-tbn3.gstatic.com/images?q=tb...
# 20  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 21  https://encrypted-tbn3.gstatic.com/images?q=tb...
# 22  https://encrypted-tbn2.gstatic.com/images?q=tb...
# 23  https://encrypted-tbn3.gstatic.com/images?q=tb...
# 24  https://encrypted-tbn3.gstatic.com/images?q=tb...
# 25  https://encrypted-tbn2.gstatic.com/images?q=tb...
# 26  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 27  https://encrypted-tbn3.gstatic.com/images?q=tb...
# 28  https://encrypted-tbn1.gstatic.com/images?q=tb...
# 29  https://encrypted-tbn3.gstatic.com/images?q=tb...
#
#                                                 title  \
# 0          “데이터와 AI를 이용한 궁극의 개인화” 고객 생애 가치 향상을 위한 ...
# 1    자율 주행에서 머신 비전까지··· 'HPC+AI' HPE 글로벌 사례 집중 분석 ...
# 2   미스트 시스템즈, 'AI 기반 셀프 드라이빙 네트워크' 발표 - ITWorld Korea
# 3    글로벌 칼럼 | AI의 밝은 면에 기업이 집중해야 할 이유 - ITWorld Korea
# 4      성공을 위한 AI 모멘텀, 성숙도, 그리고 모델 : 글로벌 경영진 설문 조사 ...
# 5       IBM, AI 혁신 기능 추가 '왓슨 애니웨어' 공개 - ITWorld Korea
# 6             운영도구의 미래도 AI에 클라우드를 더한 '클라우드옵스'가 해답 ...
# 7   “차세대 IT 인프라 운영 관리는 AI가 맡는다” HPE InfoSight가 제시하...
# 8       부산은행 '리디자인 뱅킹' 사례로 본 혁신을 위한 AI와 데이터 활용 전략 ...
# 9    글로벌 칼럼 | 보안 업체들이 말하는 AI가 정말 AI인가 - ITWorld Korea
# 10         “데이터와 AI를 이용한 궁극의 개인화” 고객 생애 가치 향상을 위한 ...
# 11   자율 주행에서 머신 비전까지··· 'HPC+AI' HPE 글로벌 사례 집중 분석 ...
# 12  미스트 시스템즈, 'AI 기반 셀프 드라이빙 네트워크' 발표 - ITWorld Korea
# 13   글로벌 칼럼 | AI의 밝은 면에 기업이 집중해야 할 이유 - ITWorld Korea
# 14     성공을 위한 AI 모멘텀, 성숙도, 그리고 모델 : 글로벌 경영진 설문 조사 ...
# 15      IBM, AI 혁신 기능 추가 '왓슨 애니웨어' 공개 - ITWorld Korea
# 16            운영도구의 미래도 AI에 클라우드를 더한 '클라우드옵스'가 해답 ...
# 17  “차세대 IT 인프라 운영 관리는 AI가 맡는다” HPE InfoSight가 제시하...
# 18      부산은행 '리디자인 뱅킹' 사례로 본 혁신을 위한 AI와 데이터 활용 전략 ...
# 19   글로벌 칼럼 | 보안 업체들이 말하는 AI가 정말 AI인가 - ITWorld Korea
# 20         “데이터와 AI를 이용한 궁극의 개인화” 고객 생애 가치 향상을 위한 ...
# 21   자율 주행에서 머신 비전까지··· 'HPC+AI' HPE 글로벌 사례 집중 분석 ...
# 22  미스트 시스템즈, 'AI 기반 셀프 드라이빙 네트워크' 발표 - ITWorld Korea
# 23   글로벌 칼럼 | AI의 밝은 면에 기업이 집중해야 할 이유 - ITWorld Korea
# 24     성공을 위한 AI 모멘텀, 성숙도, 그리고 모델 : 글로벌 경영진 설문 조사 ...
# 25      IBM, AI 혁신 기능 추가 '왓슨 애니웨어' 공개 - ITWorld Korea
# 26            운영도구의 미래도 AI에 클라우드를 더한 '클라우드옵스'가 해답 ...
# 27  “차세대 IT 인프라 운영 관리는 AI가 맡는다” HPE InfoSight가 제시하...
# 28      부산은행 '리디자인 뱅킹' 사례로 본 혁신을 위한 AI와 데이터 활용 전략 ...
# 29   글로벌 칼럼 | 보안 업체들이 말하는 AI가 정말 AI인가 - ITWorld Korea
#
#                                     link
# 0   www.itworld.co.kr/techlibrary/125010
# 1   www.itworld.co.kr/techlibrary/122105
# 2          www.itworld.co.kr/news/136382
# 3          www.itworld.co.kr/news/140144
# 4   www.itworld.co.kr/techlibrary/113328
# 5          www.itworld.co.kr/news/134755
# 6          www.itworld.co.kr/news/119435
# 7   www.itworld.co.kr/techlibrary/122990
# 8   www.itworld.co.kr/techlibrary/136998
# 9          www.itworld.co.kr/news/108702
# 10  www.itworld.co.kr/techlibrary/125010
# 11  www.itworld.co.kr/techlibrary/122105
# 12         www.itworld.co.kr/news/136382
# 13         www.itworld.co.kr/news/140144
# 14  www.itworld.co.kr/techlibrary/113328
# 15         www.itworld.co.kr/news/134755
# 16         www.itworld.co.kr/news/119435
# 17  www.itworld.co.kr/techlibrary/122990
# 18  www.itworld.co.kr/techlibrary/136998
# 19         www.itworld.co.kr/news/108702
# 20  www.itworld.co.kr/techlibrary/125010
# 21  www.itworld.co.kr/techlibrary/122105
# 22         www.itworld.co.kr/news/136382
# 23         www.itworld.co.kr/news/140144
# 24  www.itworld.co.kr/techlibrary/113328
# 25         www.itworld.co.kr/news/134755
# 26         www.itworld.co.kr/news/119435
# 27  www.itworld.co.kr/techlibrary/122990
# 28  www.itworld.co.kr/techlibrary/136998
# 29         www.itworld.co.kr/news/108702

# %%
final_df.to_csv("Tech_crunch.csv", index=False, encoding='utf-8' )
